# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import joblib

# Generate linear data without noise
np.random.seed(42)
num_samples = 1000
x = np.linspace(0, 10, num_samples)
y = 2 * x + 3  # Linear function without noise

# Function to generate random annotation points within a specified range
def generate_random_annotation_points(num_sets, num_points_per_set_min, num_points_per_set_max, x_range=(0, 10), y_range=(0, 20)):
    annotation_points_sets = []
    for _ in range(num_sets):
        num_points_per_set = np.random.randint(num_points_per_set_min, num_points_per_set_max + 1)  # Randomly choose number of points
        annotation_points = [(np.random.uniform(x_range[0], x_range[1]), np.random.uniform(y_range[0], y_range[1]))
                             for _ in range(num_points_per_set)]
        annotation_points_sets.append(annotation_points)
    return annotation_points_sets

# Train the linear regression model
model = LinearRegression()
model.fit(x.reshape(-1, 1), y)  # Reshape x to match the expected input shape

# Generate random annotation points sets with fully random number of points
num_sets = 10
num_points_per_set_min = 2  # Minimum number of points per set
num_points_per_set_max = 5  # Maximum number of points per set
annotation_points_sets = generate_random_annotation_points(num_sets, num_points_per_set_min, num_points_per_set_max)

# Save annotation points to a list
all_annotation_points = []

# Add annotation labels and calculate distances
for i, annotation_points in enumerate(annotation_points_sets):
    # Predict y values for annotation points using the model
    predicted_y = model.predict(np.array(annotation_points)[:, 0].reshape(-1, 1))

    # Update annotation_points with predicted y values
    updated_annotation_points = [(round(x_anno, 1), round(y_anno, 1)) for (x_anno, _), y_anno in zip(annotation_points, predicted_y)]

    # Append updated annotation points to the list
    all_annotation_points.extend(updated_annotation_points)

    # Print updated annotation coordinates rounded to 1 decimal place
    print(f"Updated Annotation coordinates for Set {i+1}:")
    print(updated_annotation_points)

    # Plot the linear graph with annotations
    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label='Linear Data')
    for (x_anno, y_anno) in updated_annotation_points:
        plt.scatter(x_anno, y_anno, color='red', label='Annotation Point', zorder=5)
        plt.text(x_anno, y_anno, f'({x_anno:.1f}, {y_anno:.1f})', fontsize=8, ha='right')  # Round off to 1 decimal place
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title(f'Linear Data with Annotations (Set {i+1})')
    plt.legend()
    plt.grid(True)
    plt.show()

# Save the annotation coordinates to a CSV file
annotation_df = pd.DataFrame(all_annotation_points, columns=['X', 'Y'])
annotation_df.to_csv('annotation_coordinates.csv', index=False, float_format='%.1f')

# Save the trained model to a file
joblib.dump(model, 'linear_regression_model.pkl')
# Out:
# Updated Annotation coordinates for Set 1:
# [(8.0, 18.9), (7.8, 18.6), (4.5, 11.9), (4.6, 12.2)]
# Updated Annotation coordinates for Set 2:
# [(7.1, 17.2), (9.7, 22.4), (2.1, 7.2), (1.8, 6.7), (5.2, 13.5)]
# Updated Annotation coordinates for Set 3:
# [(5.2, 13.5), (0.5, 3.9)]
# Updated Annotation coordinates for Set 4:
# [(4.6, 12.1), (2.0, 7.0), (5.9, 14.8), (6.1, 15.2)]
# Updated Annotation coordinates for Set 5:
# [(0.1, 3.3), (5.6, 14.3), (0.2, 3.3), (2.4, 7.8)]
# Updated Annotation coordinates for Set 6:
# [(5.0, 12.9), (9.1, 21.2), (6.6, 16.3), (5.2, 13.4), (1.8, 6.7)]
# Updated Annotation coordinates for Set 7:
# [(4.5, 12.0), (9.3, 21.5), (3.3, 9.5)]
# Updated Annotation coordinates for Set 8:
# [(0.5, 3.9), (3.9, 10.8), (8.3, 19.6), (2.8, 8.6), (1.4, 5.8)]
# Updated Annotation coordinates for Set 9:
# [(0.2, 3.3), (3.9, 10.9)]
# Updated Annotation coordinates for Set 10:
# [(8.2, 19.3), (7.3, 17.6), (0.7, 4.5), (1.2, 5.3)]
# ['linear_regression_model.pkl']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import joblib

# Load the trained model
model = joblib.load('linear_regression_model.pkl')

# Generate test data
np.random.seed(42)
x_test = np.linspace(0, 10, 100)
y_test_actual = 2 * x_test + 3 + np.random.normal(0, 1, 100)  # Add some random noise to simulate real-world data

# Make predictions
y_test_pred = model.predict(x_test.reshape(-1, 1))

# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(x_test, y_test_actual, color='blue', label='Actual Data')
plt.plot(x_test, y_test_pred, color='red', label='Predicted Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Actual vs. Predicted Data')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import joblib

# Generate linear data without noise
np.random.seed(42)
num_samples = 1000
x = np.linspace(0, 10, num_samples)
y = 2 * x + 3  # Linear function without noise

# Function to generate random annotation points within a specified range
def generate_random_annotation_points(num_sets, num_points_per_set_min, num_points_per_set_max, x_range=(0, 10), y_range=(0, 20)):
    annotation_points_sets = []
    for _ in range(num_sets):
        num_points_per_set = np.random.randint(num_points_per_set_min, num_points_per_set_max + 1)  # Randomly choose number of points
        annotation_points = [(np.random.uniform(x_range[0], x_range[1]), np.random.uniform(y_range[0], y_range[1]))
                             for _ in range(num_points_per_set)]
        annotation_points_sets.append(annotation_points)
    return annotation_points_sets

# Train the linear regression model
model = LinearRegression()
model.fit(x.reshape(-1, 1), y)  # Reshape x to match the expected input shape

# Save the trained model to a file
joblib.dump(model, 'linear_regression_model.pkl')

# Load the trained model from the file
loaded_model = joblib.load('linear_regression_model.pkl')

# Generate random annotation points sets with fully random number of points
num_sets = 10
num_points_per_set_min = 2  # Minimum number of points per set
num_points_per_set_max = 5  # Maximum number of points per set
annotation_points_sets = generate_random_annotation_points(num_sets, num_points_per_set_min, num_points_per_set_max)

# Save annotation points to a list
all_annotation_points = []

# Add annotation labels and calculate distances
for i, annotation_points in enumerate(annotation_points_sets):
    # Predict y values for annotation points using the loaded model
    predicted_y = loaded_model.predict(np.array(annotation_points)[:, 0].reshape(-1, 1))

    # Update annotation_points with predicted y values
    updated_annotation_points = [(round(x_anno, 1), round(y_anno, 1)) for (x_anno, _), y_anno in zip(annotation_points, predicted_y)]

    # Append updated annotation points to the list
    all_annotation_points.extend(updated_annotation_points)

    # Print updated annotation coordinates rounded to 1 decimal place
    print(f"Updated Annotation coordinates for Set {i+1}:")
    print(updated_annotation_points)

# Save the annotation coordinates to a CSV file
annotation_df = pd.DataFrame(all_annotation_points, columns=['X', 'Y'])
annotation_df.to_csv('annotation_coordinates.csv', index=False, float_format='%.1f')

# Plot the linear graph with annotations
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='Linear Data')
for (x_anno, y_anno) in all_annotation_points:
    plt.scatter(x_anno, y_anno, color='red', label='Annotation Point', zorder=5)
    plt.text(x_anno, y_anno, f'({x_anno:.1f}, {y_anno:.1f})', fontsize=8, ha='right')  # Round off to 1 decimal place
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Data with Annotations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Updated Annotation coordinates for Set 1:
# [(8.0, 18.9), (7.8, 18.6), (4.5, 11.9), (4.6, 12.2)]
# Updated Annotation coordinates for Set 2:
# [(7.1, 17.2), (9.7, 22.4), (2.1, 7.2), (1.8, 6.7), (5.2, 13.5)]
# Updated Annotation coordinates for Set 3:
# [(5.2, 13.5), (0.5, 3.9)]
# Updated Annotation coordinates for Set 4:
# [(4.6, 12.1), (2.0, 7.0), (5.9, 14.8), (6.1, 15.2)]
# Updated Annotation coordinates for Set 5:
# [(0.1, 3.3), (5.6, 14.3), (0.2, 3.3), (2.4, 7.8)]
# Updated Annotation coordinates for Set 6:
# [(5.0, 12.9), (9.1, 21.2), (6.6, 16.3), (5.2, 13.4), (1.8, 6.7)]
# Updated Annotation coordinates for Set 7:
# [(4.5, 12.0), (9.3, 21.5), (3.3, 9.5)]
# Updated Annotation coordinates for Set 8:
# [(0.5, 3.9), (3.9, 10.8), (8.3, 19.6), (2.8, 8.6), (1.4, 5.8)]
# Updated Annotation coordinates for Set 9:
# [(0.2, 3.3), (3.9, 10.9)]
# Updated Annotation coordinates for Set 10:
# [(8.2, 19.3), (7.3, 17.6), (0.7, 4.5), (1.2, 5.3)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

# Generate linear data without noise
np.random.seed(42)
num_samples = 1000
x = np.linspace(0, 10, num_samples)
y = 2 * x + 3  # Linear function without noise

# Function to generate random annotation points within a specified range
def generate_random_annotation_points(num_sets, num_points_per_set_min, num_points_per_set_max, x_range=(0, 10), y_range=(0, 20)):
    annotation_points_sets = []
    for _ in range(num_sets):
        num_points_per_set = np.random.randint(num_points_per_set_min, num_points_per_set_max + 1)  # Randomly choose number of points
        annotation_points = [(np.random.uniform(x_range[0], x_range[1]), np.random.uniform(y_range[0], y_range[1]))
                             for _ in range(num_points_per_set)]
        annotation_points_sets.append(annotation_points)
    return annotation_points_sets

# Generate random annotation points sets with fully random number of points
num_sets = 10
num_points_per_set_min = 2  # Minimum number of points per set
num_points_per_set_max = 5  # Maximum number of points per set
annotation_points_sets = generate_random_annotation_points(num_sets, num_points_per_set_min, num_points_per_set_max)

# Create DataFrame to store annotation coordinates
annotation_data = pd.DataFrame(columns=['X', 'Y', 'Set'])

# Add annotation labels and calculate distances
for i, annotation_points in enumerate(annotation_points_sets):
    temp_data = pd.DataFrame({'X': [point[0] for point in annotation_points],
                              'Y': [point[1] for point in annotation_points],
                              'Set': f'Set_{i+1}'})
    annotation_data = pd.concat([annotation_data, temp_data], ignore_index=True)

    # Print annotation coordinates
    print(f"Annotation coordinates for Set {i+1}:")
    print(temp_data.round(1))  # Round off to 1 decimal place

# Split data into features and labels
X = annotation_data.drop(columns=['Set'])  # Exclude 'Set' column from features
y = annotation_data['Set']  # Select 'Set' column as labels

# Convert categorical labels to numerical values using one-hot encoding
annotation_data_encoded = pd.get_dummies(y)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, annotation_data_encoded, test_size=0.2, random_state=42)

# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the Neural Network (Multi-layer Perceptron) model
mlp_model = MLPRegressor(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', random_state=42)
mlp_model.fit(X_train_scaled, y_train)

# Make predictions
train_predictions = mlp_model.predict(X_train_scaled)
test_predictions = mlp_model.predict(X_test_scaled)

# Calculate Mean Squared Error
train_mse = mean_squared_error(y_train, train_predictions)
test_mse = mean_squared_error(y_test, test_predictions)
print("Train Mean Squared Error:", train_mse)
print("Test Mean Squared Error:", test_mse)
# Out:
# Annotation coordinates for Set 1:
#      X     Y    Set
# 0  8.0   3.7  Set_1
# 1  7.8  11.9  Set_1
# 2  4.5   2.0  Set_1
# 3  4.6   6.7  Set_1
# Annotation coordinates for Set 2:
#      X     Y    Set
# 0  7.1   0.4  Set_2
# 1  9.7  16.6  Set_2
# 2  2.1   3.6  Set_2
# 3  1.8   6.1  Set_2
# 4  5.2   8.6  Set_2
# Annotation coordinates for Set 3:
#      X     Y    Set
# 0  5.2   8.0  Set_3
# 1  0.5  19.5  Set_3
# Annotation coordinates for Set 4:
#      X     Y    Set
# 0  4.6  15.7  Set_4
# 1  2.0  10.3  Set_4
# 2  5.9   0.9  Set_4
# 3  6.1   3.4  Set_4
# Annotation coordinates for Set 5:
#      X     Y    Set
# 0  0.1  18.8  Set_5
# 1  5.6   7.7  Set_5
# 2  0.2   4.6  Set_5
# 3  2.4  13.7  Set_5
# Annotation coordinates for Set 6:
#      X     Y    Set
# 0  5.0   0.7  Set_6
# 1  9.1   5.2  Set_6
# 2  6.6   6.2  Set_6
# 3  5.2  10.9  Set_6
# 4  1.8  19.4  Set_6
# Annotation coordinates for Set 7:
#      X     Y    Set
# 0  4.5   7.9  Set_7
# 1  9.3  14.5  Set_7
# 2  3.3  11.4  Set_7
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load the annotation data
annotation_data = pd.read_csv('annotation_coordinates.csv')

# Separate features (X) and target (Y)
X = annotation_data[['X']].values
Y = annotation_data[['Y']].values

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the neural network model
model = MLPRegressor(hidden_layer_sizes=(100, 100), activation='relu', solver='adam', random_state=42, max_iter=1000)
model.fit(X_train_scaled, y_train.ravel())

# Predict annotations for the training and test sets
y_train_pred = model.predict(X_train_scaled)
y_test_pred = model.predict(X_test_scaled)

# Calculate Mean Squared Error for training and test sets
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Train Mean Squared Error:", train_mse)
print("Test Mean Squared Error:", test_mse)

# Plot the actual vs predicted annotations for training set
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_train_pred, color='blue', label='Actual vs Predicted (Training)')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='red', linestyle='--', label='Perfect Prediction')
plt.title('Actual vs Predicted Annotations (Training Set)')
plt.xlabel('Actual Annotations')
plt.ylabel('Predicted Annotations')
plt.legend()
plt.grid(True)
plt.show()

# Plot the actual vs predicted annotations for test set
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_test_pred, color='green', label='Actual vs Predicted (Test)')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', label='Perfect Prediction')
plt.title('Actual vs Predicted Annotations (Test Set)')
plt.xlabel('Actual Annotations')
plt.ylabel('Predicted Annotations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train Mean Squared Error: 0.014719345212327302
# Test Mean Squared Error: 0.010352274182098213

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import joblib

# Load the annotation data
annotation_data = pd.read_csv('annotation_coordinates.csv')

# Print the annotation coordinates
print("Annotation Coordinates:")
for idx, row in annotation_data.iterrows():
    print(f"Annotation {idx + 1}: X = {row['X']}, Y = {row['Y']}")

# Plot all annotations
plt.figure(figsize=(8, 6))
plt.scatter(annotation_data['X'], annotation_data['Y'], color='blue', label='Annotations')
plt.title('All Annotations')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# Separate features (X) and target (Y)
X = annotation_data[['X']].values
Y = annotation_data[['Y']].values

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the neural network model
model = MLPRegressor(hidden_layer_sizes=(100, 100), activation='relu', solver='adam', random_state=42, max_iter=1000)
model.fit(X_train_scaled, y_train.ravel())

# Save the trained model to a file
joblib.dump(model, 'neural_network_model.pkl')

# Predict annotations for the training and test sets
y_train_pred = model.predict(X_train_scaled)
y_test_pred = model.predict(X_test_scaled)

# Calculate Mean Squared Error for training and test sets
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
print("Train Mean Squared Error:", train_mse)
print("Test Mean Squared Error:", test_mse)

# Plot the actual vs predicted annotations for training set
plt.figure(figsize=(10, 6))
plt.scatter(y_train, y_train_pred, color='blue', label='Actual vs Predicted (Training)')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], color='red', linestyle='--', label='Perfect Prediction')
plt.title('Actual vs Predicted Annotations (Training Set)')
plt.xlabel('Actual Annotations')
plt.ylabel('Predicted Annotations')
plt.legend()
plt.grid(True)
plt.show()

# Plot the actual vs predicted annotations for test set
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_test_pred, color='green', label='Actual vs Predicted (Test)')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', label='Perfect Prediction')
plt.title('Actual vs Predicted Annotations (Test Set)')
plt.xlabel('Actual Annotations')
plt.ylabel('Predicted Annotations')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Annotation Coordinates:
# Annotation 1: X = 8.0, Y = 18.9
# Annotation 2: X = 7.8, Y = 18.6
# Annotation 3: X = 4.5, Y = 11.9
# Annotation 4: X = 4.6, Y = 12.2
# Annotation 5: X = 7.1, Y = 17.2
# Annotation 6: X = 9.7, Y = 22.4
# Annotation 7: X = 2.1, Y = 7.2
# Annotation 8: X = 1.8, Y = 6.7
# Annotation 9: X = 5.2, Y = 13.5
# Annotation 10: X = 5.2, Y = 13.5
# Annotation 11: X = 0.5, Y = 3.9
# Annotation 12: X = 4.6, Y = 12.1
# Annotation 13: X = 2.0, Y = 7.0
# Annotation 14: X = 5.9, Y = 14.8
# Annotation 15: X = 6.1, Y = 15.2
# Annotation 16: X = 0.1, Y = 3.3
# Annotation 17: X = 5.6, Y = 14.3
# Annotation 18: X = 0.2, Y = 3.3
# Annotation 19: X = 2.4, Y = 7.8
# Annotation 20: X = 5.0, Y = 12.9
# Annotation 21: X = 9.1, Y = 21.2
# Annotation 22: X = 6.6, Y = 16.3
# Annotation 23: X = 5.2, Y = 13.4
# Annotation 24: X = 1.8, Y = 6.7
# Annotation 25: X = 4.5, Y = 12.0
# Annotation 26: X = 9.3, Y = 21.5
# Annotation 27: X = 3.3, Y = 9.5
# Annotation 28: X = 0.5, Y = 3.9
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import joblib

# Load the annotation data
annotation_data = pd.read_csv('annotation_coordinates.csv')

# Print the annotation coordinates
print("Annotation Coordinates:")
for idx, row in annotation_data.iterrows():
    print(f"Annotation {idx + 1}: X = {row['X']}, Y = {row['Y']}")

# Separate features (X) and target (Y)
X = annotation_data[['X']].values
Y = annotation_data[['Y']].values

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the neural network model
model = MLPRegressor(hidden_layer_sizes=(100, 100), activation='relu', solver='adam', random_state=42, max_iter=1000)
model.fit(X_train_scaled, y_train.ravel())

# Save the trained model to a file
joblib.dump(model, 'neural_network_model.pkl')

# Predict annotations for the training set
y_train_pred = model.predict(X_train_scaled)

# Predict annotations for the test set
y_test_pred = model.predict(X_test_scaled)

# Calculate Mean Squared Error for training set
train_mse = mean_squared_error(y_train, y_train_pred)
print("Train Mean Squared Error:", train_mse)

# Calculate Mean Squared Error for test set
test_mse = mean_squared_error(y_test, y_test_pred)
print("Test Mean Squared Error:", test_mse)

# Plot all annotations in the training set
plt.figure(figsize=(8, 6))
plt.scatter(X_train, y_train, color='blue', label='Actual Annotations (Training)')
plt.scatter(X_train, y_train_pred, color='red', label='Predicted Annotations (Training)')
plt.title('Annotations in Training Set')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()

# Plot all annotations in the test set
plt.figure(figsize=(8, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual Annotations (Test)')
plt.scatter(X_test, y_test_pred, color='red', label='Predicted Annotations (Test)')
plt.title('Annotations in Test Set')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Annotation Coordinates:
# Annotation 1: X = 8.0, Y = 18.9
# Annotation 2: X = 7.8, Y = 18.6
# Annotation 3: X = 4.5, Y = 11.9
# Annotation 4: X = 4.6, Y = 12.2
# Annotation 5: X = 7.1, Y = 17.2
# Annotation 6: X = 9.7, Y = 22.4
# Annotation 7: X = 2.1, Y = 7.2
# Annotation 8: X = 1.8, Y = 6.7
# Annotation 9: X = 5.2, Y = 13.5
# Annotation 10: X = 5.2, Y = 13.5
# Annotation 11: X = 0.5, Y = 3.9
# Annotation 12: X = 4.6, Y = 12.1
# Annotation 13: X = 2.0, Y = 7.0
# Annotation 14: X = 5.9, Y = 14.8
# Annotation 15: X = 6.1, Y = 15.2
# Annotation 16: X = 0.1, Y = 3.3
# Annotation 17: X = 5.6, Y = 14.3
# Annotation 18: X = 0.2, Y = 3.3
# Annotation 19: X = 2.4, Y = 7.8
# Annotation 20: X = 5.0, Y = 12.9
# Annotation 21: X = 9.1, Y = 21.2
# Annotation 22: X = 6.6, Y = 16.3
# Annotation 23: X = 5.2, Y = 13.4
# Annotation 24: X = 1.8, Y = 6.7
# Annotation 25: X = 4.5, Y = 12.0
# Annotation 26: X = 9.3, Y = 21.5
# Annotation 27: X = 3.3, Y = 9.5
# Annotation 28: X = 0.5, Y = 3.9
# ...

# %%
import cv2
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib
import matplotlib.pyplot as plt

# Load the trained neural network model
model = joblib.load('neural_network_model.pkl')

# Load and preprocess the image
image_path = '/content/sample_data/download1.png'
image = cv2.imread(image_path)
# Preprocess the image as needed

# Extract X values from the image (using appropriate image processing techniques)
# Example: x_values = extract_x_values(image)

# Placeholder for example x_values
x_values = np.array([1.0, 2.0, 3.0]).reshape(-1, 1)  # Replace with actual extracted X values

# Reshape the X values to comply with the StandardScaler's requirement
x_values = x_values.reshape(-1, 1)

# Instantiate a new StandardScaler object
scaler = StandardScaler()

# Fit the scaler to your X values
scaler.fit(x_values)

# Standardize features using the fitted scaler
x_values_scaled = scaler.transform(x_values)

# Predict annotations for the X values
predicted_annotations = model.predict(x_values_scaled)

# Postprocess predicted annotations if necessary (e.g., round off decimal places)

# Plot the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# Plot the predicted annotations on the image
plt.scatter(x_values, predicted_annotations, color='red', label='Predicted Annotations')

# Set plot labels and title
plt.xlabel('X Values')
plt.ylabel('Predicted Annotations')
plt.title('Predicted Annotations on Image')

# Show legend
plt.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-77bc40e30406> in <cell line: 54>()
#      52 # Show the plot
#      53 plt.show()
# ---> 54 for i, (x, y) in enumerate(xy_coordinates, start=1):
#      55     print(f"Point {i}: X = {x}, Y = {y}")
#
# NameError: name 'xy_coordinates' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout

# Preprocess the image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(299, 299))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img

# Load pre-trained InceptionV3 model without classification layers
base_model = InceptionV3(weights='imagenet', include_top=False)

# Extract image features
def extract_features(img):
    features = base_model.predict(img)
    features = tf.reshape(features, (features.shape[0], -1))  # Flatten features
    return features

# Define captioning model
embedding_dim = 256
vocab_size = 10000
max_length = 20

image_input = Input(shape=(2048,))
image_dense = Dense(embedding_dim, activation='relu')(image_input)

caption_input = Input(shape=(max_length,))
caption_embedding = Embedding(vocab_size, embedding_dim, mask_zero=True)(caption_input)
caption_lstm = LSTM(256)(caption_embedding)

decoder_input = tf.keras.layers.concatenate([image_dense, caption_lstm])
decoder_output = Dense(vocab_size, activation='softmax')(decoder_input)

captioning_model = Model(inputs=[image_input, caption_input], outputs=decoder_output)

# Compile the model
captioning_model.compile(loss='categorical_crossentropy', optimizer='adam')

# Train the model (you'll need a dataset of images and their corresponding captions)

# Generate captions for new images
img = preprocess_image('/content/sample_data/download1.png')
features = extract_features(img)
initial_caption = np.array([[word_index['<start>']]])  # Start token
for i in range(max_length):
    predicted_index = np.argmax(captioning_model.predict([features, initial_caption]))
    word = index_word[predicted_index]
    if word == '<end>':
        break
    initial_caption = np.append(initial_caption, [[predicted_index]], axis=1)

predicted_caption = ' '.join([index_word[idx] for idx in initial_caption.squeeze()])
print("Generated Caption:", predicted_caption)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Create a directory to store the generated images
dataset_dir = 'graph_dataset'
os.makedirs(dataset_dir, exist_ok=True)

# Define parameters
num_samples = 10  # Number of samples
num_points_range = (2, 5)  # Range for number of annotation points
annotation_value_range = (1, 100)  # Range for annotation values

# Generate dataset
data = []
for i in range(num_samples):
    # Generate random data points for a straight line graph
    x_values = np.arange(0, 10, 0.5)
    m, c = np.random.uniform(0.5, 2), np.random.uniform(5, 10)
    y_values = m * x_values + c

    # Select random number of annotation points
    num_points = np.random.randint(*num_points_range)

    # Randomly select indices for annotation points
    annotation_indices = np.random.choice(len(x_values), size=num_points, replace=False)

    # Generate random annotation values
    annotation_values = np.random.randint(*annotation_value_range, size=num_points)

    # Generate annotations with coordinates and values
    annotations = [f'({x_values[idx]:.1f}, {y_values[idx]:.1f}): {val}' for idx, val in zip(annotation_indices, annotation_values)]

    # Generate explanation including annotations
    explanation = f"This is a straight line graph with random annotation points and their values:\n"
    explanation += f"Equation: y = {m:.2f}x + {c:.2f}\n"
    explanation += "Annotations:\n"
    for annotation in annotations:
        explanation += f"- {annotation}\n"

    # Plot the graph
    plt.figure(figsize=(8, 6))
    plt.plot(x_values, y_values, marker='o', linestyle='-', color='b')
    for annotation in annotations:
        x, y = map(float, annotation.split('(')[1].split(')')[0].split(', '))
        plt.annotate(annotation, (x, y), textcoords="offset points", xytext=(0, 10), ha='center')
    plt.title(f'Straight Line Graph {i+1}')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.grid(True)
    plt.tight_layout()

    # Save the graph as an image
    graph_image_path = os.path.join(dataset_dir, f'straight_line_graph_{i+1}.png')
    plt.savefig(graph_image_path)
    plt.close()

    # Add data to dataset
    data.append({'image_path': graph_image_path, 'annotations': annotations, 'explanation': explanation})

# Convert dataset to DataFrame and save as CSV
df = pd.DataFrame(data)
df.to_csv(os.path.join(dataset_dir, 'graph_dataset.csv'), index=False)

# %%
## dataset code
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Create a directory to store the generated images
dataset_dir = 'graph_dataset1'
os.makedirs(dataset_dir, exist_ok=True)

# Define parameters
num_samples = 20  # Number of samples
num_points_range = (2, 5)  # Range for number of annotation points

# Generate dataset
data = []
for i in range(num_samples):
    # Generate random data points for a straight line graph
    x_values = np.arange(0, 10, 0.5)
    m, c = np.random.uniform(0.5, 2), np.random.uniform(5, 10)
    y_values = m * x_values + c

    # Select random number of annotation points
    num_points = np.random.randint(*num_points_range)

    # Randomly select indices for annotation points
    annotation_indices = np.random.choice(len(x_values), size=num_points, replace=False)

    # Generate annotations with coordinates (without values)
    annotations = [f'({x_values[idx]:.1f}, {y_values[idx]:.1f})' for idx in annotation_indices]

    # Generate explanation including annotations
    explanation = f"This is a straight line graph with random annotation points:\n"
    explanation += f"Equation: y = {m:.2f}x + {c:.2f}\n"
    explanation += "Annotations:\n"
    for annotation in annotations:
        explanation += f"- {annotation}\n"

    # Plot the graph
    plt.figure(figsize=(8, 6))
    plt.plot(x_values, y_values, linestyle='-', color='b')
    for annotation in annotations:
        if annotation.strip():  # Check if annotation has values
            x, y = map(float, annotation.split('(')[1].split(')')[0].split(', '))
            plt.scatter(x, y, color='r')
            plt.annotate(annotation, (x, y), textcoords="offset points", xytext=(0, 10), ha='center')
    plt.title(f'Straight Line Graph {i+1}')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.grid(True)
    plt.tight_layout()

    # Save the graph as an image
    graph_image_path = os.path.join(dataset_dir, f'straight_line_graph_{i+1}.png')
    plt.savefig(graph_image_path)
    plt.close()

    # Add data to dataset
    data.append({'image_path': graph_image_path, 'annotations': annotations, 'explanation': explanation})

# Convert dataset to DataFrame and save as CSV
df = pd.DataFrame(data)
df.to_csv(os.path.join(dataset_dir, 'graph_dataset1.csv'), index=False)

print("Dataset created successfully")
# Out:
# Dataset created successfully
