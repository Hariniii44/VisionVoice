# %%
import pandas as pd

# Data to be written to the CSV file
data = {
    'image': ['/content/valid_set/1_graph2.jpg', '/content/valid_set/2_graph3.jpg', '/content/valid_set/3_1.jpg','/content/valid_set/R.png','/content/valid_set/download1.png', '/content/valid_set/slide19 (1).jpg'],
    'annotations': ['none', 'none', 'none','none','(2,3),(8,6)','(1,1), (2,2), (3,3), (4,4), and (5,5) '],
    'caption': ['This is a linear graph with function f(x)=2x+2, this graph doesnt have annotations', 'This is a linear graph with function f(x)=30*0.1x+3, this graph doesnt have annotations', 'This image shows a mathematical function graph with the equation f(x) = C*a^x, where C and a are constants. The graph represents an exponential function curve with both positive and negative values as seen in the graph. This image has no annotations','This image shows a sales forecast graph with the equation Y = 88.156x + 34.584. The graph indicates the projected sales over a period, with the x-axis representing time or quantity and the y-axis representing sales amount. The values on the graph show the forecasted sales amounts at different points in time or quantity.'

,'This is a linear graph with funtion unknown and has annotations,the annotations are (2,3) and (8,6)','This image shows a linear graph with points labeled as A, B, C, D, and E. The line connecting these points forms a straight line, indicating a linear relationship between the variables x and y. The coordinates of the points are (1,1), (2,2), (3,3), (4,4), and (5,5) respectively.']
}

# Create a DataFrame
df = pd.DataFrame(data)

# Specify the file path
csv_file_path = 'valid_data.csv'

# Write DataFrame to the CSV file
df.to_csv(csv_file_path, index=False)

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
mkdir valid_set

# %%
#step1# dataset code
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Create a directory to store the generated images
dataset_dir = 'graph_dataset'
os.makedirs(dataset_dir, exist_ok=True)

# Define parameters
num_samples = 2000  # Number of samples
num_points_range = (2, 5)  # Range for number of annotation points

# Generate dataset
data = []
for i in range(num_samples):
    # Generate random data points for a straight line graph
    x_values = np.arange(0, 10, 0.5)
    m, c = np.random.uniform(0.5, 2), np.random.uniform(5, 10)
    y_values = m * x_values + c

    # Select random number of annotation points
    num_points = np.random.randint(*num_points_range)

    # Randomly select indices for annotation points
    annotation_indices = np.random.choice(len(x_values), size=num_points, replace=False)

    # Generate annotations with coordinates (without values)
    annotations = [f'({x_values[idx]:.1f}, {y_values[idx]:.1f})' for idx in annotation_indices]

    # Generate explanation including annotations
    explanation = f"This is a straight line graph with random annotation points:\n"
    explanation += f"Equation: y = {m:.2f}x + {c:.2f}\n"
    explanation += "Annotations:\n"
    for annotation in annotations:
        explanation += f"- {annotation}\n"

    # Plot the graph
    plt.figure(figsize=(8, 6))
    plt.plot(x_values, y_values, linestyle='-', color='b')
    for annotation in annotations:
        if annotation.strip():  # Check if annotation has values
            x, y = map(float, annotation.split('(')[1].split(')')[0].split(', '))
            plt.scatter(x, y, color='r')
            plt.annotate(annotation, (x, y), textcoords="offset points", xytext=(0, 10), ha='center')
    plt.title(f'Straight Line Graph {i+1}')
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.grid(True)
    plt.tight_layout()

    # Save the graph as an image
    graph_image_path = os.path.join(dataset_dir, f'straight_line_graph_{i+1}.png')
    plt.savefig(graph_image_path)
    plt.close()

    # Add data to dataset
    data.append({'image': graph_image_path, 'annotations': annotations, 'caption': explanation})

# Convert dataset to DataFrame and save as CSV
df = pd.DataFrame(data)
df.to_csv(os.path.join(dataset_dir, 'graph_dataset.csv'), index=False)

print("Dataset created successfully")
# Out:
# Dataset created successfully

# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, Dropout, Flatten, Dense, Input, Layer
from tensorflow.keras.layers import Embedding, LSTM, add, Concatenate, Reshape, concatenate, Bidirectional
from tensorflow.keras.applications import VGG16, ResNet50, DenseNet201
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from textwrap import wrap

plt.rcParams['font.size'] = 12
sns.set_style("dark")
warnings.filterwarnings('ignore')

# %%
image_path = '/content/graph_dataset'

# %%
data = pd.read_csv("/content/graph_dataset/graph_dataset.csv")
data.head()
# Out:
#                                      image  \
# 0  graph_dataset/straight_line_graph_1.png
# 1  graph_dataset/straight_line_graph_2.png
# 2  graph_dataset/straight_line_graph_3.png
# 3  graph_dataset/straight_line_graph_4.png
# 4  graph_dataset/straight_line_graph_5.png
#
#                                          annotations  \
# 0  ['(4.0, 11.5)', '(5.0, 12.8)', '(5.5, 13.5)', ...
# 1       ['(0.0, 7.2)', '(6.5, 12.1)', '(4.0, 10.2)']
# 2  ['(7.0, 11.4)', '(4.0, 9.7)', '(5.0, 10.2)', '...
# 3                      ['(1.0, 9.7)', '(7.5, 18.8)']
# 4                     ['(7.0, 11.9)', '(6.5, 11.6)']
#
#                                              caption
# 0  This is a straight line graph with random anno...
# 1  This is a straight line graph with random anno...
# 2  This is a straight line graph with random anno...
# 3  This is a straight line graph with random anno...
# 4  This is a straight line graph with random anno...

# %%
from PIL import Image

def readImage(image_path):
    """
    Read an image from the specified file path.

    Parameters:
        image_path (str): The file path of the image.

    Returns:
        image: The image object.
    """
    image = Image.open(image_path)
    return image

def display_images(temp_df):
    temp_df = temp_df.reset_index(drop=True)
    plt.figure(figsize=(20, 20))
    n = 0
    for i in range(15):
        n += 1
        plt.subplot(5, 5, n)
        plt.subplots_adjust(hspace=0.7, wspace=0.3)
        image_path = os.path.join("/content", temp_df.image[i])  # Corrected file path
        image = readImage(image_path)
        plt.imshow(image)
        plt.title("\n".join(wrap(temp_df.caption[i], 20)))
        plt.axis("off")

# %%
display_images(data.sample(15))

# %%
def text_preprocessing(data):
    data['caption'] = data['caption'].apply(lambda x: x.lower())
    data['caption'] = data['caption'].apply(lambda x: x.replace("[^A-Za-z]",""))
    data['caption'] = data['caption'].apply(lambda x: x.replace("\s+"," "))
    data['caption'] = data['caption'].apply(lambda x: " ".join([word for word in x.split() if len(word)>1]))
    data['caption'] = "startseq "+data['caption']+" endseq"
    return data

# %%
data = text_preprocessing(data)
captions = data['caption'].tolist()
captions[:10]
# Out:
# ['startseq this is straight line graph with random annotation points: equation: 1.35x 6.10 annotations: (4.0, 11.5) (5.0, 12.8) (5.5, 13.5) (2.5, 9.5) endseq',
#  'startseq this is straight line graph with random annotation points: equation: 0.75x 7.20 annotations: (0.0, 7.2) (6.5, 12.1) (4.0, 10.2) endseq',
#  'startseq this is straight line graph with random annotation points: equation: 0.56x 7.45 annotations: (7.0, 11.4) (4.0, 9.7) (5.0, 10.2) (1.5, 8.3) endseq',
#  'startseq this is straight line graph with random annotation points: equation: 1.40x 8.31 annotations: (1.0, 9.7) (7.5, 18.8) endseq',
#  'startseq this is straight line graph with random annotation points: equation: 0.73x 6.84 annotations: (7.0, 11.9) (6.5, 11.6) endseq',
#  'startseq this is straight line graph with random annotation points: equation: 1.12x 9.21 annotations: (9.5, 19.8) (2.0, 11.5) (1.5, 10.9) endseq',
# ...

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(captions)
vocab_size = len(tokenizer.word_index) + 1
max_length = max(len(caption.split()) for caption in captions)

images = data['image'].unique().tolist()
nimages = len(images)

split_index = round(0.85*nimages)
train_images = images[:split_index]
val_images = images[split_index:]

train = data[data['image'].isin(train_images)]
test = data[data['image'].isin(val_images)]

train.reset_index(inplace=True,drop=True)
test.reset_index(inplace=True,drop=True)

tokenizer.texts_to_sequences([captions[1]])[0]

# %%
model = DenseNet201()
fe = Model(inputs=model.input, outputs=model.layers[-2].output)
image_path = '/content/'  # Update the image_path to the correct directory

img_size = 224
features = {}
for image in tqdm(data['image'].unique().tolist()):
    img = load_img(os.path.join(image_path,image),target_size=(img_size,img_size))
    img = img_to_array(img)
    img = img/255.
    img = np.expand_dims(img,axis=0)
    feature = fe.predict(img, verbose=0)
    features[image] = feature
# Out:
# ...
# 100%|██████████| 2000/2000 [11:28<00:00,  2.91it/s]

# %%
class CustomDataGenerator(Sequence):

    def __init__(self, df, X_col, y_col, batch_size, directory, tokenizer,
                 vocab_size, max_length, features,shuffle=True):

        self.df = df.copy()
        self.X_col = X_col
        self.y_col = y_col
        self.directory = directory
        self.batch_size = batch_size
        self.tokenizer = tokenizer
        self.vocab_size = vocab_size
        self.max_length = max_length
        self.features = features
        self.shuffle = shuffle
        self.n = len(self.df)

    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

    def __len__(self):
        return self.n // self.batch_size

    def __getitem__(self,index):

        batch = self.df.iloc[index * self.batch_size:(index + 1) * self.batch_size,:]
        X1, X2, y = self.__get_data(batch)
        return (X1, X2), y

    def __get_data(self,batch):

        X1, X2, y = list(), list(), list()

        images = batch[self.X_col].tolist()

        for image in images:
            feature = self.features[image][0]

            captions = batch.loc[batch[self.X_col]==image, self.y_col].tolist()
            for caption in captions:
                seq = self.tokenizer.texts_to_sequences([caption])[0]

                for i in range(1,len(seq)):
                    in_seq, out_seq = seq[:i], seq[i]
                    in_seq = pad_sequences([in_seq], maxlen=self.max_length)[0]
                    out_seq = to_categorical([out_seq], num_classes=self.vocab_size)[0]
                    X1.append(feature)
                    X2.append(in_seq)
                    y.append(out_seq)

        X1, X2, y = np.array(X1), np.array(X2), np.array(y)

        return X1, X2, y

# %%
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Reshape, concatenate, Dropout, add
from tensorflow.keras.models import Model

# Define the maximum length for text input
max_length = 100
vocab_size = 10000

# Define the inputs
input1 = Input(shape=(1920,))
input2 = Input(shape=(max_length,))

# Extract features from the image
img_features = Dense(256, activation='relu')(input1)
img_features_reshaped = Reshape((1, 256))(img_features)

# Process text input
sentence_features = Embedding(vocab_size, 256, mask_zero=False)(input2)

# Combine image and text features
merged = concatenate([img_features_reshaped, sentence_features], axis=1)
sentence_features = LSTM(256)(merged)
x = Dropout(0.5)(sentence_features)
x = add([x, img_features])
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(vocab_size, activation='softmax')(x)

caption_model = Model(inputs=[input1, input2], outputs=output)
caption_model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(caption_model)

# %%
caption_model.summary()

# %%
train_generator = CustomDataGenerator(df=train,X_col='image',y_col='caption',batch_size=64,directory=image_path,
                                      tokenizer=tokenizer,vocab_size=vocab_size,max_length=max_length,features=features)

validation_generator = CustomDataGenerator(df=test,X_col='image',y_col='caption',batch_size=64,directory=image_path,
                                      tokenizer=tokenizer,vocab_size=vocab_size,max_length=max_length,features=features)

# %%
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer

# Example text data
texts = train['caption']  # Assuming 'caption' is the column name containing text data

# Initialize the tokenizer
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(texts)

# Now you can use the tokenizer to tokenize your text data

# Load training data from CSV file
train = pd.read_csv('/content/graph_dataset/graph_dataset.csv')

# Define other necessary variables such as image_path, tokenizer, vocab_size, max_length, and features

# Now you can use train to create your data generator
train_generator = CustomDataGenerator(df=train, X_col='image', y_col='caption', batch_size=64, directory=image_path,
                                      tokenizer=tokenizer, vocab_size=vocab_size, max_length=max_length, features=features)
validation_generator = CustomDataGenerator(df=train, X_col='image', y_col='caption', batch_size=64, directory=image_path,
                                      tokenizer=tokenizer, vocab_size=vocab_size, max_length=max_length, features=features)

# %%
model_name = "model.h5"
checkpoint = ModelCheckpoint(model_name,
                            monitor="val_loss",
                            mode="min",
                            save_best_only = True,
                            verbose=1)

earlystopping = EarlyStopping(monitor='val_loss',min_delta = 0, patience = 5, verbose = 1, restore_best_weights=True)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                            patience=3,
                                            verbose=1,
                                            factor=0.2,
                                            min_lr=0.00000001)

# %% [markdown]
# history = caption_model.fit(
#         train_generator,
#         epochs=10,
#         validation_data=validation_generator,
#         callbacks=[checkpoint,earlystopping,learning_rate_reduction])

# %%
history = caption_model.fit( train_generator, epochs=15, validation_data=validation_generator, callbacks=[checkpoint,earlystopping,learning_rate_reduction])
# Out:
# Epoch 1/15
# 31/31 [==============================] - ETA: 0s - loss: 5.0574
# Epoch 1: val_loss improved from inf to 3.64752, saving model to model.h5
# 31/31 [==============================] - 538s 17s/step - loss: 5.0574 - val_loss: 3.6475 - lr: 0.0010
# Epoch 2/15
# 31/31 [==============================] - ETA: 0s - loss: 3.6982
# Epoch 2: val_loss improved from 3.64752 to 3.59807, saving model to model.h5
# 31/31 [==============================] - 537s 17s/step - loss: 3.6982 - val_loss: 3.5981 - lr: 0.0010
# Epoch 3/15
# 31/31 [==============================] - ETA: 0s - loss: 3.6035
# Epoch 3: val_loss improved from 3.59807 to 3.51514, saving model to model.h5
# 31/31 [==============================] - 537s 17s/step - loss: 3.6035 - val_loss: 3.5151 - lr: 0.0010
# Epoch 4/15
# 31/31 [==============================] - ETA: 0s - loss: 3.3031
# Epoch 4: val_loss improved from 3.51514 to 2.79440, saving model to model.h5
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Define callbacks
model_name = "model.h5"
checkpoint = ModelCheckpoint(model_name, monitor="val_loss", mode="min", save_best_only=True, verbose=1)
earlystopping = EarlyStopping(monitor='loss', min_delta=0, patience=5, verbose=1, restore_best_weights=True)
learning_rate_reduction = ReduceLROnPlateau(monitor='loss', patience=3, verbose=1, factor=0.2, min_lr=0.00000001)

# Fit the model
history = caption_model.fit(train_generator, epochs=20, validation_data=validation_generator, callbacks=[checkpoint, earlystopping, learning_rate_reduction])

# %%
plt.figure(figsize=(20,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
def idx_to_word(integer,tokenizer):

    for word, index in tokenizer.word_index.items():
        if index==integer:
            return word
    return None

# %%
def predict_caption(model, image, tokenizer, max_length, features):

    feature = features[image]
    in_text = "startseq"
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], max_length)

        y_pred = model.predict([feature,sequence])
        y_pred = np.argmax(y_pred)

        word = idx_to_word(y_pred, tokenizer)

        if word is None:
            break

        in_text+= " " + word

        if word == 'endseq':
            break

    return in_text

# %%
samples = test.sample(15)
samples.reset_index(drop=True,inplace=True)

# %%
for index,record in samples.iterrows():

    img = load_img(os.path.join(image_path,record['image']),target_size=(224,224))
    img = img_to_array(img)
    img = img/255.

    caption = predict_caption(caption_model, record['image'], tokenizer, max_length, features)
    samples.loc[index,'caption'] = caption
# Out:
# ...
# 1/1 [==============================] - 0s 48ms/step
# ...
# ...
# 1/1 [==============================] - 0s 66ms/step

# %%
display_images(samples)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import tensorflow as tf

# Load the image
img_path = '/content/sample_data/2_graph3.jpg'
img = image.load_img(img_path, target_size=(8, 1920))  # Resize to match the expected input shape

# Convert the image to an array
img_array = image.img_to_array(img)
img_array = np.array(img_array)  # Create a copy of the array

# Flatten the image array
img_array = img_array.flatten()

# Reshape the flattened array to match the expected input shape of the model
img_array = img_array.reshape((1, 1920))

# Predict with the model
prediction = caption_model.predict([img_array, np.zeros((1, max_length))])  # Assuming max_length is the maximum length of captions
predicted_caption_index = np.argmax(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-1c8ae83601c7> in <cell line: 18>()
#      16
#      17 # Reshape the flattened array to match the expected input shape of the model
# ---> 18 img_array = img_array.reshape((1, 1920))
#      19
#      20 # Predict with the model
#
# ValueError: cannot reshape array of size 46080 into shape (1,1920)
