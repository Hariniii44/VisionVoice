# %%
import os
import shutil
import random
import matplotlib.pyplot as plt
import numpy as np

# Function to create and save different types of graphs
def create_graphs(num_samples=1000, target_dir='graph_target/'):
    # Create target directory if it doesn't exist
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)

    # Generate graphs for each class
    for i in range(num_samples):
        plt.figure(figsize=(6, 4))  # Adjust the figure size as needed

        # Generate random data for the graph
        x = np.arange(10)
        y = np.random.randint(1, 10, size=10)

        # Choose a random graph type
        graph_type = np.random.choice(['line', 'bar', 'pie', 'scatter'])

        # Plot the graph
        if graph_type == 'line':
            plt.plot(x, y)
        elif graph_type == 'bar':
            plt.bar(x, y)
        elif graph_type == 'pie':
            plt.pie(y, labels=x)
        elif graph_type == 'scatter':
            plt.scatter(x, y)

        plt.title(f'{graph_type.capitalize()} Graph')
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')

        # Determine the class directory based on the graph type
        class_dir = os.path.join(target_dir, graph_type)

        # Create the class directory if it doesn't exist
        if not os.path.exists(class_dir):
            os.makedirs(class_dir)

        # Save the generated graph in the corresponding class directory
        plt.savefig(os.path.join(class_dir, f'graph_{i}.png'))
        plt.close()

# Create the dataset with the corrected directory structure
create_graphs(num_samples=1000)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define data generators for training and validation
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# Directory paths for source and target datasets
source_dir = '/content/graph_images/'  # Original dataset directory
target_dir = '/content/graph_target'  # Directory to save target dataset

train_generator = train_datagen.flow_from_directory(
    source_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',  # Set class_mode to 'categorical' for multi-class classification
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    source_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',  # Set class_mode to 'categorical' for multi-class classification
    subset='validation'
)

# Load pre-trained ResNet50 model
base_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base model layers
base_model.trainable = False

# Add custom classification head
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(4, activation='softmax')(x)  # Assuming 4 classes of graphs

# Create model
model = tf.keras.Model(inputs=base_model.input, outputs=output)

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(train_generator, epochs=10, validation_data=val_generator)
# Out:
# Found 0 images belonging to 1 classes.
# Found 0 images belonging to 1 classes.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-aa16e15096c8> in <cell line: 44>()
#      42
#      43 # Train model
# ---> 44 history = model.fit(train_generator, epochs=10, validation_data=val_generator)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in __getitem__(self, idx)
#     101     def __getitem__(self, idx):
#     102         if idx >= len(self):
# --> 103             raise ValueError(
#     104                 "Asked to retrieve element {idx}, "
#     105                 "but the Sequence "
#
# ValueError: Asked to retrieve element 0, but the Sequence has length 0

# %%
import os

# 1. Print out the list of files in the directories
print("Files in 'graph_images/':", os.listdir('graph_images/'))
print("Files in 'graph_target/':", os.listdir('graph_target/'))

# 2. Verify directory structure
for root, dirs, files in os.walk('graph_images/'):
    print(f"Directory structure in 'graph_images/': {root}")
    print(f"Subdirectories: {dirs}")
    print(f"Files: {files}")

# 3. Check image formats and count
image_formats = ['.jpg', '.jpeg', '.png', '.gif']  # Supported image formats
image_count = 0
for root, dirs, files in os.walk('graph_images/'):
    for file in files:
        if os.path.splitext(file)[1].lower() in image_formats:
            image_count += 1

print(f"Total number of images in 'graph_images/': {image_count}")

# 4. Check permissions
print(f"Permissions for 'graph_images/': Readable? {os.access('graph_images/', os.R_OK)}, Writable? {os.access('graph_images/', os.W_OK)}")
print(f"Permissions for 'graph_target/': Readable? {os.access('graph_target/', os.R_OK)}, Writable? {os.access('graph_target/', os.W_OK)}")
# Out:
# Files in 'graph_images/': ['graph_257.png', 'graph_761.png', 'graph_241.png', 'graph_304.png', 'graph_733.png', 'graph_779.png', 'graph_976.png', 'graph_580.png', 'graph_192.png', 'graph_288.png', 'graph_230.png', 'graph_981.png', 'graph_535.png', 'graph_269.png', 'graph_721.png', 'graph_433.png', 'graph_818.png', 'graph_608.png', 'graph_94.png', 'graph_577.png', 'graph_718.png', 'graph_990.png', 'graph_291.png', 'graph_808.png', 'graph_224.png', 'graph_996.png', 'graph_92.png', 'graph_641.png', 'graph_549.png', 'graph_501.png', 'graph_524.png', 'graph_895.png', 'graph_253.png', 'graph_62.png', 'graph_790.png', 'graph_619.png', 'graph_277.png', 'graph_787.png', 'graph_719.png', 'graph_837.png', 'graph_615.png', 'graph_966.png', 'graph_800.png', 'graph_596.png', 'graph_391.png', 'graph_887.png', 'graph_756.png', 'graph_485.png', 'graph_859.png', 'graph_907.png', 'graph_474.png', 'graph_547.png', 'graph_366.png', 'graph_460.png', 'graph_302.png', 'graph_419.png', 'graph_361.png', 'graph_973.png', 'graph_839.png', 'graph_149.png', 'graph_7.png', 'graph_815.png', 'graph_560.png', 'graph_129.png', 'graph_215.png', 'graph_697.png', 'graph_207.png', 'graph_865.png', 'graph_329.png', 'graph_83.png', 'graph_868.png', 'graph_609.png', 'graph_543.png', 'graph_188.png', 'graph_689.png', 'graph_409.png', 'graph_528.png', 'graph_832.png', 'graph_378.png', 'graph_332.png', 'graph_140.png', 'graph_985.png', 'graph_693.png', 'graph_33.png', 'graph_991.png', 'graph_194.png', 'graph_536.png', 'graph_296.png', 'graph_660.png', 'graph_603.png', 'graph_52.png', 'graph_600.png', 'graph_238.png', 'graph_358.png', 'graph_927.png', 'graph_289.png', 'graph_567.png', 'graph_58.png', 'graph_884.png', 'graph_61.png', 'graph_931.png', 'graph_634.png', 'graph_371.png', 'graph_135.png', 'graph_314.png', 'graph_284.png', 'graph_825.png', 'graph_310.png', 'graph_393.png', 'graph_60.png', 'graph_625.png', 'graph_807.png', 'graph_132.png', 'graph_512.png', 'graph_499.png', 'graph_606.png', 'graph_385.png', 'graph_461.png', 'graph_788.png', 'graph_151.png', 'graph_824.png', 'graph_130.png', 'graph_957.png', 'graph_344.png', 'graph_242.png', 'graph_134.png', 'graph_758.png', 'graph_850.png', 'graph_739.png', 'graph_11.png', 'graph_126.png', 'graph_456.png', 'graph_919.png', 'graph_844.png', 'graph_822.png', 'graph_78.png', 'graph_853.png', 'graph_665.png', 'graph_924.png', 'graph_613.png', 'graph_307.png', 'graph_102.png', 'graph_440.png', 'graph_225.png', 'graph_627.png', 'graph_233.png', 'graph_992.png', 'graph_143.png', 'graph_998.png', 'graph_326.png', 'graph_232.png', 'graph_71.png', 'graph_707.png', 'graph_694.png', 'graph_785.png', 'graph_93.png', 'graph_349.png', 'graph_435.png', 'graph_897.png', 'graph_507.png', 'graph_827.png', 'graph_846.png', 'graph_896.png', 'graph_148.png', 'graph_852.png', 'graph_712.png', 'graph_112.png', 'graph_30.png', 'graph_381.png', 'graph_328.png', 'graph_727.png', 'graph_532.png', 'graph_254.png', 'graph_537.png', 'graph_44.png', 'graph_582.png', 'graph_630.png', 'graph_562.png', 'graph_27.png', 'graph_406.png', 'graph_828.png', 'graph_15.png', 'graph_8.png', 'graph_659.png', 'graph_891.png', 'graph_538.png', 'graph_350.png', 'graph_729.png', 'graph_894.png', 'graph_803.png', 'graph_156.png', 'graph_982.png', 'graph_529.png', 'graph_823.png', 'graph_984.png', 'graph_611.png', 'graph_637.png', 'graph_892.png', 'graph_437.png', 'graph_43.png', 'graph_175.png', 'graph_886.png', 'graph_709.png', 'graph_282.png', 'graph_343.png', 'graph_57.png', 'graph_944.png', 'graph_163.png', 'graph_105.png', 'graph_451.png', 'graph_471.png', 'graph_394.png', 'graph_365.png', 'graph_414.png', 'graph_669.png', 'graph_158.png', 'graph_445.png', 'graph_496.png', 'graph_505.png', 'graph_798.png', 'graph_355.png', 'graph_481.png', 'graph_177.png', 'graph_77.png', 'graph_843.png', 'graph_527.png', 'graph_187.png', 'graph_79.png', 'graph_964.png', 'graph_866.png', 'graph_893.png', 'graph_231.png', 'graph_861.png', 'graph_141.png', 'graph_969.png', 'gr ...
# Files in 'graph_target/': ['graph_680', 'graph_12', 'graph_822', 'graph_131', 'graph_445', 'graph_985', 'graph_868', 'graph_183', 'graph_201', 'graph_175', 'graph_641', 'graph_609', 'graph_49', 'graph_255', 'graph_6', 'graph_426', 'graph_127', 'graph_537', 'graph_57', 'graph_84', 'graph_132', 'graph_779', 'graph_307', 'graph_487', 'graph_529', 'graph_104', 'graph_697', 'graph_22', 'graph_56', 'graph_112', 'graph_95', 'graph_235', 'graph_189', 'graph_767', 'graph_34', 'graph_165', 'graph_377', 'graph_129', 'graph_889', 'graph_791', 'graph_757', 'graph_845', 'graph_481', 'graph_194', 'graph_339', 'graph_325', 'graph_784', 'graph_109', 'graph_665', 'graph_989', 'graph_847', 'graph_43', 'graph_582', 'graph_881', 'graph_286', 'graph_96', 'graph_600', 'graph_615', 'graph_134', 'graph_373', 'graph_193', 'graph_964', 'graph_951', 'graph_207', 'graph_808', 'graph_163', 'graph_736', 'graph_21', 'graph_864', 'graph_210', 'graph_778', 'graph_87', 'graph_803', 'graph_762', 'graph_414', 'graph_741', 'graph_627', 'graph_548', 'graph_299', 'graph_594', 'graph_820', 'graph_854', 'graph_986', 'graph_977', 'graph_547', 'graph_932', 'graph_700', 'graph_291', 'graph_80', 'graph_10', 'graph_743', 'graph_168', 'graph_407', 'graph_423', 'graph_225', 'graph_683', 'graph_114', 'graph_929', 'graph_652', 'graph_938', 'graph_768', 'graph_839', 'graph_278', 'graph_978', 'graph_480', 'graph_399', 'graph_997', 'graph_185', 'graph_876', 'graph_438', 'graph_500', 'graph_382', 'graph_861', 'graph_704', 'graph_282', 'graph_370', 'graph_461', 'graph_930', 'graph_412', 'graph_82', 'graph_555', 'graph_879', 'graph_379', 'graph_40', 'graph_238', 'graph_605', 'graph_387', 'graph_317', 'graph_637', 'graph_719', 'graph_607', 'graph_887', 'graph_224', 'graph_908', 'graph_980', 'graph_51', 'graph_535', 'graph_509', 'graph_634', 'graph_147', 'graph_245', 'graph_915', 'graph_788', 'graph_136', 'graph_261', 'graph_488', 'graph_138', 'graph_462', 'graph_897', 'graph_97', 'graph_23', 'graph_505', 'graph_851', 'graph_811', 'graph_303', 'graph_575', 'graph_503', 'graph_797', 'graph_789', 'graph_340', 'graph_623', 'graph_443', 'graph_447', 'graph_440', 'graph_242', 'graph_501', 'graph_724', 'graph_622', 'graph_298', 'graph_872', 'graph_155', 'graph_415', 'graph_643', 'graph_691', 'graph_502', 'graph_883', 'graph_759', 'graph_755', 'graph_259', 'graph_645', 'graph_304', 'graph_824', 'graph_337', 'graph_271', 'graph_250', 'graph_375', 'graph_866', 'graph_479', 'graph_952', 'graph_427', 'graph_815', 'graph_532', 'graph_30', 'graph_213', 'graph_178', 'graph_769', 'graph_367', 'graph_947', 'graph_355', 'graph_570', 'graph_969', 'graph_583', 'graph_885', 'graph_167', 'graph_709', 'graph_514', 'graph_356', 'graph_737', 'graph_871', 'graph_949', 'graph_391', 'graph_4', 'graph_943', 'graph_603', 'graph_675', 'graph_297', 'graph_828', 'graph_991', 'graph_408', 'graph_344', 'graph_987', 'graph_639', 'graph_220', 'graph_425', 'graph_316', 'graph_636', 'graph_263', 'graph_492', 'graph_374', 'graph_217', 'graph_28', 'graph_813', 'graph_195', 'graph_76', 'graph_917', 'graph_877', 'graph_334', 'graph_435', 'graph_393', 'graph_310', 'graph_35', 'graph_324', 'graph_475', 'graph_667', 'graph_312', 'graph_416', 'graph_459', 'graph_671', 'graph_950', 'graph_279', 'graph_413', 'graph_456', 'graph_598', 'graph_24', 'graph_482', 'graph_77', 'graph_162', 'graph_945', 'graph_36', 'graph_835', 'graph_181', 'graph_805', 'graph_191', 'graph_260', 'graph_794', 'graph_734', 'graph_773', 'graph_239', 'graph_903', 'graph_208', 'graph_302', 'graph_29', 'graph_934', 'graph_296', 'graph_988', 'graph_720', 'graph_429', 'graph_581', 'graph_19', 'graph_121', 'graph_689', 'graph_88', 'graph_381', 'graph_364', 'graph_26', 'graph_243', 'graph_161', 'graph_617', 'graph_678', 'graph_395', 'graph_465', 'graph_390', 'graph_933', 'graph_44', 'graph_436', 'graph_489', 'graph_234', 'graph_739', 'graph_865', 'graph_976', 'graph_396', 'graph_442', 'graph_179', 'graph_295', 'graph_962', 'graph_256', 'graph_886', 'graph_428', 'gra ...
# Directory structure in 'graph_images/': graph_images/
# Subdirectories: []
# Files: ['graph_257.png', 'graph_761.png', 'graph_241.png', 'graph_304.png', 'graph_733.png', 'graph_779.png', 'graph_976.png', 'graph_580.png', 'graph_192.png', 'graph_288.png', 'graph_230.png', 'graph_981.png', 'graph_535.png', 'graph_269.png', 'graph_721.png', 'graph_433.png', 'graph_818.png', 'graph_608.png', 'graph_94.png', 'graph_577.png', 'graph_718.png', 'graph_990.png', 'graph_291.png', 'graph_808.png', 'graph_224.png', 'graph_996.png', 'graph_92.png', 'graph_641.png', 'graph_549.png', 'graph_501.png', 'graph_524.png', 'graph_895.png', 'graph_253.png', 'graph_62.png', 'graph_790.png', 'graph_619.png', 'graph_277.png', 'graph_787.png', 'graph_719.png', 'graph_837.png', 'graph_615.png', 'graph_966.png', 'graph_800.png', 'graph_596.png', 'graph_391.png', 'graph_887.png', 'graph_756.png', 'graph_485.png', 'graph_859.png', 'graph_907.png', 'graph_474.png', 'graph_547.png', 'graph_366.png', 'graph_460.png', 'graph_302.png', 'graph_419.png', 'graph_361.png', 'graph_973.png', 'graph_839.png', 'graph_149.png', 'graph_7.png', 'graph_815.png', 'graph_560.png', 'graph_129.png', 'graph_215.png', 'graph_697.png', 'graph_207.png', 'graph_865.png', 'graph_329.png', 'graph_83.png', 'graph_868.png', 'graph_609.png', 'graph_543.png', 'graph_188.png', 'graph_689.png', 'graph_409.png', 'graph_528.png', 'graph_832.png', 'graph_378.png', 'graph_332.png', 'graph_140.png', 'graph_985.png', 'graph_693.png', 'graph_33.png', 'graph_991.png', 'graph_194.png', 'graph_536.png', 'graph_296.png', 'graph_660.png', 'graph_603.png', 'graph_52.png', 'graph_600.png', 'graph_238.png', 'graph_358.png', 'graph_927.png', 'graph_289.png', 'graph_567.png', 'graph_58.png', 'graph_884.png', 'graph_61.png', 'graph_931.png', 'graph_634.png', 'graph_371.png', 'graph_135.png', 'graph_314.png', 'graph_284.png', 'graph_825.png', 'graph_310.png', 'graph_393.png', 'graph_60.png', 'graph_625.png', 'graph_807.png', 'graph_132.png', 'graph_512.png', 'graph_499.png', 'graph_606.png', 'graph_385.png', 'graph_461.png', 'graph_788.png', 'graph_151.png', 'graph_824.png', 'graph_130.png', 'graph_957.png', 'graph_344.png', 'graph_242.png', 'graph_134.png', 'graph_758.png', 'graph_850.png', 'graph_739.png', 'graph_11.png', 'graph_126.png', 'graph_456.png', 'graph_919.png', 'graph_844.png', 'graph_822.png', 'graph_78.png', 'graph_853.png', 'graph_665.png', 'graph_924.png', 'graph_613.png', 'graph_307.png', 'graph_102.png', 'graph_440.png', 'graph_225.png', 'graph_627.png', 'graph_233.png', 'graph_992.png', 'graph_143.png', 'graph_998.png', 'graph_326.png', 'graph_232.png', 'graph_71.png', 'graph_707.png', 'graph_694.png', 'graph_785.png', 'graph_93.png', 'graph_349.png', 'graph_435.png', 'graph_897.png', 'graph_507.png', 'graph_827.png', 'graph_846.png', 'graph_896.png', 'graph_148.png', 'graph_852.png', 'graph_712.png', 'graph_112.png', 'graph_30.png', 'graph_381.png', 'graph_328.png', 'graph_727.png', 'graph_532.png', 'graph_254.png', 'graph_537.png', 'graph_44.png', 'graph_582.png', 'graph_630.png', 'graph_562.png', 'graph_27.png', 'graph_406.png', 'graph_828.png', 'graph_15.png', 'graph_8.png', 'graph_659.png', 'graph_891.png', 'graph_538.png', 'graph_350.png', 'graph_729.png', 'graph_894.png', 'graph_803.png', 'graph_156.png', 'graph_982.png', 'graph_529.png', 'graph_823.png', 'graph_984.png', 'graph_611.png', 'graph_637.png', 'graph_892.png', 'graph_437.png', 'graph_43.png', 'graph_175.png', 'graph_886.png', 'graph_709.png', 'graph_282.png', 'graph_343.png', 'graph_57.png', 'graph_944.png', 'graph_163.png', 'graph_105.png', 'graph_451.png', 'graph_471.png', 'graph_394.png', 'graph_365.png', 'graph_414.png', 'graph_669.png', 'graph_158.png', 'graph_445.png', 'graph_496.png', 'graph_505.png', 'graph_798.png', 'graph_355.png', 'graph_481.png', 'graph_177.png', 'graph_77.png', 'graph_843.png', 'graph_527.png', 'graph_187.png', 'graph_79.png', 'graph_964.png', 'graph_866.png', 'graph_893.png', 'graph_231.png', 'graph_861.png', 'graph_141.png', 'graph_969.png', 'graph_570.png', 'grap ...
# Total number of images in 'graph_images/': 1000
# Permissions for 'graph_images/': Readable? True, Writable? True
# Permissions for 'graph_target/': Readable? True, Writable? True

# %%
import os
import shutil

# Path to the original dataset directory
source_dir = '/content/graph_images/'

# Create a list of class names (you may need to adapt this based on your dataset)
class_names = ['class_1', 'class_2', 'class_3', ...]

# Iterate over each class
for class_name in class_names:
    # Create the subdirectory for the class if it doesn't exist
    class_dir = os.path.join(source_dir, class_name)
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

    # Move the images corresponding to the class into the subdirectory
    class_images = [f for f in os.listdir(source_dir) if f.startswith(class_name)]
    for image in class_images:
        shutil.move(os.path.join(source_dir, image), os.path.join(class_dir, image))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.10/shutil.py in move(src, dst, copy_function)
#     815     try:
# --> 816         os.rename(src, real_dst)
#     817     except OSError:
#
# OSError: [Errno 22] Invalid argument: '/content/graph_images/class_1' -> '/content/graph_images/class_1/class_1'
#
# During handling of the above exception, another exception occurred:
#
# Error                                     Traceback (most recent call last)
# <ipython-input-14-0b0d2b7ff13b> in <cell line: 11>()
#      18     class_images = [f for f in os.listdir(source_dir) if f.startswith(class_name)]
#      19     for image in class_images:
# ---> 20         shutil.move(os.path.join(source_dir, image), os.path.join(class_dir, image))
#      21
#
# /usr/lib/python3.10/shutil.py in move(src, dst, copy_function)
#     822         elif os.path.isdir(src):
#     823             if _destinsrc(src, dst):
# --> 824                 raise Error("Cannot move a directory '%s' into itself"
#     825                             " '%s'." % (src, dst))
#     826             if (_is_immutable(src)
#
# Error: Cannot move a directory '/content/graph_images/class_1' into itself '/content/graph_images/class_1/class_1'.
